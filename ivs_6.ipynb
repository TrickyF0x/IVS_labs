# %% [markdown]
# <a href="https://colab.research.google.com/github/Gelani-G/NL_lab6/blob/main/NL_lab6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Интеллектуальные вычислительные системы
#Семенков Алексей 420-М1
#Лабораторная работа №6 Исследование влияния параметров алгоритмов и нечеткой системы на сходимость алгоритмов идентификации
#Вариант 7 (19 номер в списке, вариантов 12, 19-12=7)
# Функция: z = y * sin(x+y)

# %%
import matplotlib.pyplot as plt

# %%
GEN_5 = [0.25163015187638643, 0.26557597782932096, 0.2549766002335639, 0.23512323010143707, 0.24051957647282407]

GEN_7 = [0.17227317730583486, 0.17904202752160625, 0.17514986780033884, 0.18815292665681232, 0.18018984697363208]

GEN_9 = [0.14119411382128427, 0.1461786071392979, 0.14812844776421927, 0.1459484942127289, 0.14675287870228443]

fix, ax = plt.subplots()
ax.set_title('Генетический аглоритм с разным количеством термов')
ax.plot([5, 5, 5, 5, 5], GEN_5, '+', label='5 термов')
ax.plot([7, 7, 7, 7, 7], GEN_7, '+', label='7 термов')
ax.plot([9, 9, 9, 9, 9], GEN_9, '+', label='9 термов')
plt.legend()

# %%
ANT_5 = [0.1634936652787614, 0.19765420331388192, 0.169665394732821, 0.18696215906039598, 0.1634936652787614]

ANT_7 = [0.11311026315521398, 0.15114994701951812, 0.1282549830161864, 0.1183250161849864, 0.1284325019886164]

ANT_9 = [0.09619123726213981, 0.10139446689934029, 0.0848326973664105, 0.09619123726213981, 0.11336246026463861]

fix,ax = plt.subplots()
ax.set_title('Муравьиный алгоритм с разным количеством термов')
ax.plot([5, 5, 5, 5, 5], ANT_5, '+', label='5 термов')
ax.plot([7, 7, 7, 7, 7], ANT_7, '+', label='7 термов')
ax.plot([9, 9, 9, 9, 9], ANT_9, '+', label='9 термов')
plt.legend()

# %%
GEN_POPULATION_10 = [0.14119411382128427, 0.1461786071392979, 0.14812844776421927, 0.1459484942127289, 0.14675287870228443]

GEN_POPULATION_50 = [0.14917489114508564, 0.14259746504421822, 0.14992454892501886, 0.1407447124195935, 0.14295181783461947]

GEN_POPULATION_100 = [0.1412718681859228, 0.14688531681654332, 0.144352577623909, 0.13907884787388025, 0.14012504130085327]

fig, ax = plt.subplots()
ax.set_title('Генетический алгоритм с разными значениями популяции')
ax.plot([10, 10, 10, 10, 10], GEN_POPULATION_10, '+', label='10 особей')
ax.plot([50, 50, 50, 50, 50], GEN_POPULATION_50, '+', label='50 особей')
ax.plot([100, 100, 100, 100, 100], GEN_POPULATION_100, '+', label='100 особей')
ax.legend()

# %%
# Муравьиный алгоритм c разными значениями популяции
ANT_POPULATION_10 = [1.3987759975, 1.318875810124, 1.375668485, 1.3857664124, 1.39734913]

ANT_POPULATION_50 = [1.149985875, 0.9958577125, 1.058775125, 0.877752120958, 1.012599585]

ANT_POPULATION_100 = [0.7832959235, 0.69881285, 0.788587235, 0.8858757135, 0.75991295851]

fig, ax = plt.subplots()
ax.set_title('Муравьиный алгоритм c разными значениями популяции')
ax.plot([10, 10, 10, 10, 10], ANT_POPULATION_10, '+', label='10 особей')
ax.plot([50, 50, 50, 50, 50], ANT_POPULATION_50, '+', label='50 особей')
ax.plot([100, 100, 100, 100, 100], ANT_POPULATION_100, '+', label='100 особей')
ax.legend()

# %%
# генетический алгоритм максимальная СКО при 2, 3, 4 эелементов мутации
GEN_MUTATION_1 = [0.28278756122164456, 0.28059818755810406, 0.2697596079823449, 0.27553124334695994, 0.26996056825953973]

GEN_MUTATION_2 = [0.2696124194907887, 0.2732860570048019, 0.26340967937628197, 0.2717612039370215, 0.2819310247039841]

GEN_MUTATION_3 = [0.2820189444083204, 0.2760740889743264, 0.25757333094575074, 0.271025865971136, 0.27066300570593366]

fig, ax = plt.subplots()
ax.set_title('Генетический алгоритм с разными значениями количества элементов мутации')
ax.plot([1, 1, 1, 1, 1], GEN_MUTATION_1, '+', label='2 элемента')
ax.plot([2, 2, 2, 2, 2], GEN_MUTATION_2, '+', label='3 элемента')
ax.plot([3, 3, 3, 3, 3], GEN_MUTATION_3, '+', label='4 элемента')
ax.legend()

# %%
# алгоритм муравьиной колонии с различными значениями альфы (Коэффициент снижения интенсивности фермента)
ANT_ALPHA_0DOT5 = [1.359684894, 1.337775995, 1.36715645, 1.39775845, 1.328766545]

ANT_ALPHA_1 = [0.78837431, 0.87759917, 0.638576749, 0.87561615, 0.627577835]

ANT_ALPHA_1DOT5 = [1.3886759405, 1.2975775989, 1.25877695, 1.35488475, 1.488587125]

fig, ax = plt.subplots()
ax.set_title('Муравьиный алгоритм с разными значениями коэффициента снижения интенсивности фермента')
ax.plot([0.5, 0.5, 0.5, 0.5, 0.5], ANT_ALPHA_0DOT5, '+', label='коэффициент 0.5')
ax.plot([1, 1, 1, 1, 1], ANT_ALPHA_1, '+', label='коэффициент 1')
ax.plot([1.5, 1.5, 1.5, 1.5, 1.5], ANT_ALPHA_1DOT5, '+', label='коэффициент 1.5')
ax.legend()
